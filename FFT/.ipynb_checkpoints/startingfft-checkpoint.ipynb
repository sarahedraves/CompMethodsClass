# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
numpoints=1000
numbins=16

# %%
points=np.random.normal(size=(2,numpoints))

# %%
plt.scatter(points[0],points[1])

# %% [markdown]
# make a grid from -3.5 to 3.5 with intervals of one and sort points into them, so almost all points go in a bin and the bins are centered on whole numbers - after testing a few different methods i remembered that the histrogram method can just do this for me lol. also don't even need to divide by area to get density because the area of each box will just be 1 with a 1x1 grid. or could make it flexible for different numbers of boxes.

# %%
counts,xedges,yedges=np.histogram2d(points[0],points[1],bins=(numbins,numbins))

# %%
deltax=xedges[1]-xedges[0]

# %%
binarea=deltax**2

# %%
density=counts/binarea

# %%
plt.imshow(density, extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]])

# %% [markdown]
# make a function to take the points and compute the bin densities each time

# %%
# def densities(points,numbins):
#     counts,xedges,yedges=np.histogram2d(points[0],points[1],bins=(numbins,numbins))
#     binarea=(xedges[1]-xedges[0])**2
#     density=counts/binarea
#     return density,xedges,yedges

# %% [markdown]
# hmmm this would actually mean you are drawing a new grid each time. probably best to generate the edges once at the beginning and then keep the same grid? let's iterate once before writing methods

# %%
fftdensity=np.fft.fft2(density)

# %%
fftdensity.shape
# Out:
# (16, 16)

# %% [markdown]
# returning to the 2D version after better understanding the process from the 1D version

# %%
deltak=2*np.pi/deltax #switch to scipy version so that it gives the ks
deltal=deltak

# %%
#1D version of k
#k=np.arange(1,numbins+1)
#k=k*deltak

# %% [markdown]
# according to this https://atmos.washington.edu/~breth/classes/AM585/lect/FS_2DPoisson.pdf, instead of dividing by k^2, divide by k^2+l^2 where k and l correspond to the coordinates of the cell

# %%
kl = np.array([[[i, j] for j in range(1,numbins+1)] for i in range(1,numbins+1)], dtype=object) #from chatgpt
#this should have gone from -n/2 to n/2

# %%
kl=kl*deltak #these are the coordinates in fourier space

# %%
kl2=np.array([[coord[0]**2 + coord[1]**2 for coord in row] for row in kl]) #from chatgpt

# %%
fftpotential=-fftdensity/kl2 #will have to set this to 0 for the k=0

# %%
potential=np.fft.ifft2(fftpotential) #is it okay to just do the real part here? 
#not sure why the inverse returns complex numbers although the complex parts are small

# %%
potential
# Out:
# array([[-0.03101917+2.28411430e-03j, -0.03137506+4.95154212e-03j,
#         -0.03264087+7.50360405e-03j, -0.03469796+9.59876905e-03j,
#         -0.03762275+1.13372371e-02j, -0.04184834+1.15616703e-02j,
#         -0.0459351 +9.63992936e-03j, -0.04842551+5.98952372e-03j,
#         -0.0493713 +1.75445246e-03j, -0.04782202-2.49349578e-03j,
#         -0.04479096-5.35405988e-03j, -0.0409827 -6.68289200e-03j,
#         -0.03745609-6.27956524e-03j, -0.03486587-4.97365529e-03j,
#         -0.03255302-2.90601642e-03j, -0.03139182-3.50773656e-04j],
#        [-0.03172258+4.67147177e-03j, -0.03172566+7.52726864e-03j,
#         -0.0326788 +1.04065976e-02j, -0.03452311+1.29641215e-02j,
#         -0.03736378+1.52507775e-02j, -0.04188903+1.61837723e-02j,
#         -0.04674594+1.48332210e-02j, -0.04993662+1.12146214e-02j,
#         -0.05137298+6.57312824e-03j, -0.05006442+2.03811638e-03j,
#         -0.04754944-1.30939780e-03j, -0.04381445-3.42918923e-03j,
#         -0.04006689-3.76627465e-03j, -0.03660615-2.72574688e-03j,
#         -0.0340026 -6.37390236e-04j, -0.03245868+1.93354625e-03j],
#        [-0.03335933-4.56034630e-03j, -0.03489613-1.79390634e-03j,
#         -0.03734459+4.39360971e-04j, -0.04054704+2.00707438e-03j,
#         -0.04470865+2.75091028e-03j, -0.05025068+8.45988644e-04j,
#         -0.05342922-3.83725969e-03j, -0.05440828-9.18487864e-03j,
#         -0.05243489-1.39281631e-02j, -0.04932699-1.75858741e-02j,
#         -0.04446879-1.92888855e-02j, -0.03982928-1.86222162e-02j,
#         -0.03626451-1.65570049e-02j, -0.03422494-1.38471559e-02j,
#         -0.03278363-1.07257867e-02j, -0.03265606-7.55203663e-03j],
#        [-0.03176363-2.46325636e-03j, -0.03288696+1.42794794e-04j,
#         -0.03488897+2.39183017e-03j, -0.03770024+4.06054146e-03j,
#         -0.04134972+4.88220939e-03j, -0.04582045+3.65510688e-03j,
#         -0.04936368+3.30441846e-04j, -0.0509486 -4.53513509e-03j,
#         -0.04994631-8.99365692e-03j, -0.04690606-1.26306941e-02j,
#         -0.04321998-1.44786407e-02j, -0.0388521 -1.45304544e-02j,
#         -0.03550554-1.29763379e-02j, -0.03325465-1.07635183e-02j,
#         -0.03179413-8.02942926e-03j, -0.03139572-5.20293172e-03j],
#        [-0.03103465-8.20814827e-05j, -0.03176326+2.51173185e-03j,
#         -0.03338832+4.89311851e-03j, -0.03596296+6.67865536e-03j,
#         -0.03901176+7.88649682e-03j, -0.04344223+7.42106168e-03j,
#         -0.04736056+4.63986698e-03j, -0.04876691+3.32863495e-04j,
#         -0.04849517-3.67323095e-03j, -0.0465428 -7.34919905e-03j,
#         -0.04329822-9.75005451e-03j, -0.03933109-1.04100002e-02j,
#         -0.0359468 -9.45791956e-03j, -0.03353233-7.64860881e-03j,
#         -0.0318051 -5.32735357e-03j, -0.03103805-2.71391895e-03j]])

# %%
potentialghosts=np.pad(potential, pad_width=1, mode='edge')

# %% [markdown]
# now... how to compute the gradient in 2d? hmm - can just use numpy gradient method or look up 2d centered difference method
# https://numpy.org/doc/stable/reference/generated/numpy.gradient.html

# %%
gradx,grady=np.gradient(potentialghosts, deltax, deltax)

# %%
grady
# Out:
# array([[ 0.00000000e+00, -4.59981090e-04, -2.09601733e-03,
#         -4.29478005e-03, -6.43897722e-03, -9.24171584e-03,
#         -1.07435411e-02, -8.50085658e-03, -4.44121053e-03,
#          7.80003184e-04,  5.91998890e-03,  8.83967766e-03,
#          9.48016714e-03,  7.90588073e-03,  6.33712818e-03,
#          4.49013338e-03,  1.50082338e-03,  0.00000000e+00],
#        [ 0.00000000e+00, -4.59981090e-04, -2.09601733e-03,
#         -4.29478005e-03, -6.43897722e-03, -9.24171584e-03,
#         -1.07435411e-02, -8.50085658e-03, -4.44121053e-03,
#          7.80003184e-04,  5.91998890e-03,  8.83967766e-03,
#          9.48016714e-03,  7.90588073e-03,  6.33712818e-03,
#          4.49013338e-03,  1.50082338e-03,  0.00000000e+00],
#        [ 0.00000000e+00, -3.97837982e-06, -1.23589435e-03,
#         -3.61564054e-03, -6.05523648e-03, -9.52030239e-03,
#         -1.21262491e-02, -1.04013527e-02, -5.98034996e-03,
#         -1.65172443e-04,  4.94183803e-03,  8.07795744e-03,
#          9.67104898e-03,  9.31657932e-03,  7.83796907e-03,
#          5.36051163e-03,  1.99547584e-03,  0.00000000e+00],
#         -1.89752506e-02, -1.20584868e-02,  1.69735986e-04,
#          1.07596978e-02,  1.74433731e-02,  1.98599597e-02,
#          1.63059529e-02,  9.87902442e-03,  6.82257365e-03,
#          3.07722563e-03,  1.20298183e-05,  0.00000000e+00],
#        [ 0.00000000e+00, -2.73435595e-03, -6.96907906e-03,
#         -9.73654122e-03, -1.20038897e-02, -1.53222848e-02,
#         -1.60588525e-02, -1.02156891e-02,  8.75659672e-04,
#          1.13290208e-02,  1.58933696e-02,  1.72130002e-02,
#          1.44650211e-02,  8.86385871e-03,  5.18757090e-03,
#          1.93515398e-03, -5.76372811e-05,  0.00000000e+00],
#        [ 0.00000000e+00, -2.42866501e-03, -6.39911839e-03,
#         -8.71373135e-03, -1.07716073e-02, -1.37208604e-02,
#         -1.43606938e-02, -6.53446381e-03,  3.46772452e-03,
#          8.92721756e-03,  1.24188005e-02,  1.45293382e-02,
#          1.20228403e-02,  7.38258911e-03,  4.86206765e-03,
#          1.76842200e-03, -3.01672307e-05,  0.00000000e+00],
#        [ 0.00000000e+00, -1.98628245e-03, -5.15086385e-03,
#         -7.30368278e-03, -9.51790052e-03, -1.25417600e-02,
#         -1.12711520e-02, -5.37360488e-03,  1.28514051e-03,
#          6.56746304e-03,  1.02960312e-02,  1.22755882e-02,
#          1.06038622e-02,  7.24349345e-03,  4.49896448e-03,
#          2.02774435e-03,  1.64876944e-04,  0.00000000e+00],
#        [ 0.00000000e+00, -1.45188582e-03, -4.03944235e-03,
#         -6.22106341e-03, -8.35037920e-03, -1.04952078e-02,
#         -1.03578842e-02, -6.62802482e-03, -7.53037266e-04,
#          5.22489560e-03,  8.69364548e-03,  1.04095788e-02,
#          9.97075487e-03,  7.23459770e-03,  4.79692598e-03,
#          2.40262827e-03,  5.14935218e-04,  0.00000000e+00],
#        [ 0.00000000e+00, -9.41709040e-04, -3.04207267e-03,
#         -5.42803188e-03, -7.26817662e-03, -9.66680197e-03,
#         -1.07906537e-02, -6.88203961e-03, -1.46645471e-03,
#          2.87462131e-03,  6.71694267e-03,  9.32098514e-03,
#          9.50156633e-03,  7.49477087e-03,  5.35306022e-03,
#          3.22381361e-03,  9.91396880e-04,  0.00000000e+00],
#        [ 0.00000000e+00, -9.41709040e-04, -3.04207267e-03,
#         -5.42803188e-03, -7.26817662e-03, -9.66680197e-03,
#         -1.07906537e-02, -6.88203961e-03, -1.46645471e-03,
#          2.87462131e-03,  6.71694267e-03,  9.32098514e-03,
#          9.50156633e-03,  7.49477087e-03,  5.35306022e-03,
#          3.22381361e-03,  9.91396880e-04,  0.00000000e+00]])

# %%
vt0=np.zeros((2,numpoints))

# %%
vt1=np.zeros((2,numpoints))

# %%
xlabels=np.digitize(points[0,:].round(5),xedges.round(5),right=True)

# %%
ylabels=np.digitize(points[1,:].round(5),yedges.round(5),right=True)

# %%
deltat=1

# %%
for i in range(numpoints):
    ixbin=xlabels[i]
    iybin=ylabels[i]
    vt1[0,i]=vt0[0,i]-deltat*gradx[ixbin,iybin] #update velocity by adding acceleration (negative potential gradient times deltat)
    vt1[1,i]=vt0[1,i]-deltat*grady[ixbin,iybin] 
#would work better with leapfrog method for calculating velocities

# %%
points=points+vt1*deltat

# %%
plt.hist2d(points[0,:],points[1,:],[xedges,yedges])
plt.show()
